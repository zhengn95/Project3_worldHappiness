# %% [markdown]
# The below Data Visualizations Track includes visualizations created with Python using matplotlib, Pandas library, libraries that include scipy, seaborn, geopy and linear regression analysis. The python script visualization library includes additional visualiations that are not in our presentation but included here as part of our workflow to get a deeper understanding of the dtaset by running different variations.

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from pathlib import Path

# %%
#Read path with Pandas
Happiness_data = pd.read_csv('world-happiness-report-2021.csv')
Happiness_data
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
# Get info on the Dataset
Happiness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
#Get a statistical summary of the dataframe
Happiness_data.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
#Creating a pie chart for happiness scores
# Group the data by 'Regional indicator' and sum the 'Ladder score'
region_scores = Happiness_data.groupby('Regional indicator')['Ladder score'].sum()

# Create the pie chart
plt.figure(figsize=(10, 8))
plt.pie(region_scores, labels=region_scores.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Set the title
plt.title('Happiness Score Distribution by Region')

# Show the pie chart
plt.show()

# Optionally, save the figure
plt.savefig('happiness_score_by_region.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# List of columns to plot against the Ladder score
columns_to_plot = ['Social support', 'Freedom to make life choices', 'Logged GDP per capita', 'Generosity', 'Healthy life expectancy']

# Initialize a figure
plt.figure(figsize=(14, 8))

# Plot each column against the Ladder score
for column in columns_to_plot:
    sns.lineplot(data=Happiness_data, x='Ladder score', y=column, label=column)

# Add title and labels
plt.title('Factors Influencing Happiness Score')
plt.xlabel('Happiness Score (Ladder Score)')
plt.ylabel('Values')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Calculate the mean 'Ladder score' for each 'Regional indicator'
mean_scores = Happiness_data.groupby('Regional indicator')['Ladder score'].mean().reset_index()

# Sort the regions by the mean score in descending order
mean_scores = mean_scores.sort_values('Ladder score', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 7))
barplot = sns.barplot(x='Ladder score', y='Regional indicator', data=mean_scores, palette='coolwarm')

# Add the values on the bars
for index, value in enumerate(mean_scores['Ladder score']):
    plt.text(value, index, f'{value:.2f}')

# Set the title and labels
plt.title('Average Happiness Score by Region')
plt.xlabel('Average Happiness Score')
plt.ylabel('Region')

# Show the plot
plt.show()

# Optionally, save the plot
plt.savefig('average_happiness_score_by_region.png')

# %%
# Group the data by 'Regional indicator' and calculate the mean of 'Social support'
social_support_means = df.groupby('Regional indicator')['Social support'].mean()
Freedom_to_make_life_choices = df.groupby('Regional indicator')['Freedom to make life choices'].mean()
Logged_GDP_percapita = df.groupby('Regional indicator')['Logged GDP per capita'].mean()
Healthy_life_expectancy = df.groupby('Regional indicator')['Healthy life expectancy'].mean()
Freedom_to_make_life_choices = df.groupby('Regional indicator')['Freedom to make life choices'].mean()
Generosity = df.groupby('Regional indicator')['Generosity'].mean()

#  print the mean values
print(social_support_means)
print(Freedom_to_make_life_choices)
print(Logged_GDP_percapita)
print(Healthy_life_expectancy)
print(Freedom_to_make_life_choices)
print(Generosity)
# Out:
# Regional indicator
# Central and Eastern Europe            0.887412
# Commonwealth of Independent States    0.872500
# East Asia                             0.860500
# Latin America and Caribbean           0.839500
# Middle East and North Africa          0.797647
# North America and ANZ                 0.933500
# South Asia                            0.703429
# Southeast Asia                        0.820333
# Sub-Saharan Africa                    0.696750
# Western Europe                        0.914476
# Name: Social support, dtype: float64
# Regional indicator
# Central and Eastern Europe            0.797059
# Commonwealth of Independent States    0.816917
# East Asia                             0.763500
# Latin America and Caribbean           0.831750
# Middle East and North Africa          0.716471
# North America and ANZ                 0.898750
# South Asia                            0.765000
# Southeast Asia                        0.909000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plotting mean Freedom to make life choices by Region
Freedom_to_make_life_choices = df.groupby('Regional indicator')['Freedom to make life choices'].mean().sort_values(ascending=False)
plt.figure(figsize=(14, 7))
sns.lineplot(x=Freedom_to_make_life_choices.index, y=Freedom_to_make_life_choices, marker='o')
plt.title('Freedom to Make Life Choices by Region')
plt.xlabel('Region')
plt.ylabel('Mean Freedom to Make Life Choices')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting mean Social Support by Region
social_support_means = df.groupby('Regional indicator')['Social support'].mean().sort_values(ascending=False)
plt.figure(figsize=(14, 7))
sns.lineplot(x=social_support_means.index, y=social_support_means, marker='o')
plt.title('Social Support by Region')
plt.xlabel('Region')
plt.ylabel('Mean Social Support')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Generosity = df.groupby('Regional indicator')['Generosity'].mean().sort_values(ascending=False)
plt.figure(figsize=(14, 7))
sns.lineplot(x=Generosity.index, y=Generosity, marker='o')
plt.title('Generosity by Region')
plt.xlabel('Region')
plt.ylabel('Generosity per Capita')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
Logged_GDP_percapita = df.groupby('Regional indicator')['Logged GDP per capita'].mean().sort_values(ascending=False)
plt.figure(figsize=(14, 7))
sns.lineplot(x=Logged_GDP_percapita.index, y=Logged_GDP_percapita, marker='o')
plt.title('Logged GDP per Capita by Region')
plt.xlabel('Region')
plt.ylabel('Mean Logged GDP per Capita')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting mean Healthy life expectancy by Region
life_expectancy = df.groupby('Regional indicator')['Healthy life expectancy'].mean().sort_values(ascending=False)
plt.figure(figsize=(14, 7))
sns.lineplot(x=life_expectancy.index, y=life_expectancy, marker='o')
plt.title('Healthy Life Expectancy by Region')
plt.xlabel('Region')
plt.ylabel('Mean Healthy Life Expectancy')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Combining all of the variables into one graph to produce a clean output is challenging as social support being one of the higher markers for happiness did not plot well on our consolidated graph. This is noted in the workflow for analysis purposes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# List of variables to analyze
variables = ['Healthy life expectancy', 'Social support', 'Freedom to make life choices', 
             'Generosity', 'Logged GDP per capita']

# Ensure the DataFrame only contains numeric data for the variables
df_numeric = Happiness_data[variables].apply(pd.to_numeric, errors='coerce')

# Calculate the mean of each variable for each region
mean_values = Happiness_data.groupby('Regional indicator')[variables].mean()

# Transpose the DataFrame for plotting
mean_values_transposed = mean_values.T

# Plotting all mean variables on one graph
plt.figure(figsize=(14, 10))

# Plot each variable on the same graph
for variable in mean_values_transposed.index:
    sorted_mean_values = mean_values_transposed.loc[variable].sort_values(ascending=False)
    sns.lineplot(data=sorted_mean_values, label=variable)

plt.title('Mean Happiness Factors by Region')
plt.xlabel('Region')
plt.xticks(rotation=90)
plt.ylabel('Mean Values')
plt.legend(title='Happiness Factors')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data creation
# Assuming df is the DataFrame with the relevant data
data = {
    'Regional indicator': ['Western Europe', 'North America and ANZ', 'Middle East and North Africa',
                           'Latin America and Caribbean', 'Central and Eastern Europe', 'East Asia',
                           'Southeast Asia', 'Commonwealth of Independent States', 'Sub-Saharan Africa',
                           'South Asia'],
    'Social support': [0.9, 0.92, 0.87, 0.88, 0.75, 0.77, 0.79, 0.82, 0.67, 0.62],
    'Freedom to make life choices': [0.8, 0.85, 0.7, 0.72, 0.68, 0.65, 0.6, 0.7, 0.5, 0.4],
    'Logged GDP per capita': [10.7, 10.9, 9.7, 9.3, 10, 10.1, 9.5, 9.8, 8.7, 8.2],
    'Generosity': [0.2, 0.19, 0.08, 0.1, 0.12, 0.14, 0.25, 0.2, 0.15, 0.3],
    'Healthy life expectancy': [72, 71, 68, 70, 67, 65, 64, 66, 55, 60]
}

df = pd.DataFrame(data)

# Variables to be plotted
variables = ['Social support', 'Freedom to make life choices', 'Logged GDP per capita', 'Generosity', 'Healthy life expectancy']

# Set the style
sns.set(style="whitegrid")

# Initialize a figure
plt.figure(figsize=(14, 8))

# Plot each variable
for var in variables:
    # Calculate the mean for each region and variable
    means = df.groupby('Regional indicator')[var].mean()
    # Normalize the means if the variable is 'Social support' to match the scale [0, 1]
    if var == 'Social support':
        max_value = means.max()
        min_value = means.min()
        means = (means - min_value) / (max_value - min_value)
    # Sort values for better readability
    means = means.sort_values(ascending=False)
    # Plot
    sns.lineplot(x=means.index, y=means, label=var)

# Finalize the plot
plt.title('Mean Happiness Factors by Region')
plt.xlabel('Region')
plt.ylabel('Mean Values (Normalized for Social Support)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

# %%
# Adjusting the script to expand the y-axis to show all happiness factors including 'Social support'

# Set the style
sns.set(style="whitegrid")

# Initialize a figure
plt.figure(figsize=(14, 8))

# Find the global minimum and maximum across all variables to set y-axis limits
global_min = df[variables].min().min()
global_max = df[variables].max().max()

# Plot each variable
for var in variables:
    # Calculate the mean for each region and variable
    means = df.groupby('Regional indicator')[var].mean()
    # Sort values for better readability
    means = means.sort_values(ascending=False)
    # Plot
    sns.lineplot(x=means.index, y=means, label=var)

# Finalize the plot
plt.title('Mean Happiness Factors by Region')
plt.xlabel('Region')
plt.ylabel('Mean Values')
plt.xticks(rotation=90)
plt.legend()
plt.ylim(global_min - 0.1 * (global_max - global_min),  # Slightly lower than the global min
         global_max + 0.1 * (global_max - global_min))  # Slightly higher than the global max

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Sample data/mean ladder score used to get understanding of Happiness scores by country

# Sample data
data = {
    'Country name': ['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 
                     'Norway', 'Sweden', 'Luxembourg', 'New Zealand', 'Austria', 
                     'Australia', 'Israel', 'Germany', 'Canada', 'Ireland', 
                     'Costa Rica', 'United Kingdom', 'Czech Republic', 'United States', 'Belgium', 
                     'France', 'Bahrain', 'Malta', 'Taiwan', 'United Arab Emirates', 
                     'Saudi Arabia', 'Spain', 'Italy', 'Slovenia', 'Guatemala', 
                     'Uruguay', 'Singapore', 'Kosovo', 'Slovakia', 'Brazil', 
                     'Mexico', 'Jamaica', 'Lithuania', 'Cyprus', 'Estonia', 
                     'Panama', 'Uzbekistan', 'Chile', 'Poland', 'Kazakhstan', 
                     'Slovakia', 'Kuwait', 'Serbia', 'El Salvador', 'Malaysia', 
                     'Vietnam'],
    'Ladder score': [7.842, 7.620, 7.571, 7.554, 7.464, 7.392, 7.363, 7.324, 7.277, 7.268, 
                     7.183, 7.157, 7.155, 7.103, 7.085, 7.069, 7.064, 6.965, 6.951, 6.834, 
                     6.690, 6.647, 6.602, 6.584, 6.561, 6.494, 6.491, 6.483, 6.461, 6.435, 
                     6.431, 6.377, 6.372, 6.331, 6.330, 6.317, 6.309, 6.255, 6.223, 6.189, 
                     6.180, 6.179, 6.172, 6.166, 6.152, 6.140, 6.106, 6.078, 6.061, 6.049, 
                     6.039]
}

df = pd.DataFrame(data)

# Sort the countries by their ladder score in descending order to get the ranking
df_sorted = df.sort_values('Ladder score', ascending=False)

# Plotting the bar chart of happiness ranking
plt.figure(figsize=(20, 15))
sns.barplot(x='Ladder score', y='Country name', data=df_sorted)

# Adding the ladder score value on each bar
for index, value in enumerate(df_sorted['Ladder score']):
    plt.text(value, index, f'{value:.2f}')

plt.title('Happiness Ranking of Countries')
plt.xlabel('Happiness Score (Ladder Score)')
plt.ylabel('Country')
plt.tight_layout()  # Ensure everything fits without overlap

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Sample data to represent the 15 happiest countries based on ladder score
data = {
    'Country name': ['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands',
                     'Norway', 'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
                     'Australia', 'Israel', 'Germany', 'Canada', 'Ireland'],
    'Ladder score': [7.842, 7.620, 7.571, 7.554, 7.464,
                     7.392, 7.363, 7.324, 7.277, 7.268,
                     7.183, 7.157, 7.155, 7.103, 7.085]
}

df = pd.DataFrame(data)

# Sort the DataFrame by ladder score in descending order
df_sorted = df.sort_values('Ladder score', ascending=False)

# Plotting the bar chart for the top 15 happiest countries
plt.figure(figsize=(12, 8))  # Adjust size as needed
sns.barplot(x='Ladder score', y='Country name', data=df_sorted, palette='viridis')

plt.title('Top 15 Happiest Countries Based on Ladder Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data for the bottom 15 countries based on the ladder score from the screenshot
data = {
    'Country name': [
        'Sierra Leone', 'India', 'Togo', 'Yemen', 'Burundi', 
        'South Sudan', 'Central African Republic', 'Tanzania', 'Afghanistan', 'Lebanon', 
        'Zimbabwe', 'Rwanda', 'Botswana', 'Lesotho', 'Malawi'
    ],
    'Ladder score': [
        3.849, 3.819, 4.107, 3.658, 3.775, 
        2.816, 3.476, 3.623, 2.523, 2.955, 
        3.145, 3.415, 3.467, 3.512, 3.615
    ]
}

df = pd.DataFrame(data)

# Sort the countries by ladder score in descending order
df_sorted = df.sort_values('Ladder score', ascending=False)

# Plot the bar chart for the bottom 15 countries
plt.figure(figsize=(12, 8))
sns.barplot(x='Ladder score', y='Country name', data=df_sorted, palette='coolwarm')

# Set the title and labels for the plot
plt.title('Bottom 15 Countries by Happiness Ladder Score (Descending Order)')
plt.xlabel('Happiness Ladder Score')
plt.ylabel('Country')

plt.tight_layout()  # Adjust layout for better readability
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd

# Sample data for the top and bottom 15 countries with their ladder scores and coordinates
data = {
    'Country name': [
        # Top 15 countries
        'Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 
        'Norway', 'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
        'Australia', 'Israel', 'Germany', 'Canada', 'Ireland',
        # Bottom 15 countries
        'Afghanistan', 'Lesotho', 'Botswana', 'Rwanda', 'Zimbabwe', 
        'South Sudan', 'Central African Republic', 'Tanzania', 'Yemen', 'Malawi'
    ],
    'Ladder score': [
        7.842, 7.620, 7.571, 7.554, 7.464, 
        7.392, 7.363, 7.324, 7.277, 7.268,
        7.183, 7.157, 7.155, 7.103, 7.085,
        3.203, 3.512, 3.467, 3.415, 3.145, 
        2.816, 3.476, 3.623, 3.658, 3.615
    ],
    'Latitude': [
        61.92, 56.26, 46.82, 64.96, 52.13,
        60.47, 63.74, 49.61, -40.90, 47.20,
        -25.27, 31.77, 51.16, 56.13, 53.41,
        34.53, -29.61, -22.33, -1.94, -20.15,
        4.85, 6.61, -6.37, 15.55, -13.25
    ],
    'Longitude': [
        25.74, 9.50, 8.23, -19.02, 5.29,
        8.47, 18.64, 6.13, 174.78, 14.55,
        133.78, 34.75, 10.45, -106.34, -7.95,
        67.71, 28.23, 24.68, 30.06, 29.15,
        31.31, 20.94, 34.89, 48.52, 34.30
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Set up the map with cartopy
fig, ax = plt.subplots(figsize=(40, 35), subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.LAND.with_scale('110m'), facecolor='lightgray')
ax.add_feature(cfeature.COASTLINE.with_scale('110m'))
ax.add_feature(cfeature.BORDERS.with_scale('110m'), linestyle=':')

# Set a larger font size for better readability
font_size = 10  # Adjust the size as needed

# Plot each country's ladder score with larger markers and brighter colors
for idx, row in df.iterrows():
    # Assign color based on ladder score
    color = 'red' if row['Ladder score'] < 5 else 'green'
    ax.plot(row['Longitude'], row['Latitude'], 'o', color=color, transform=ccrs.Geodetic(), markersize=7)
    plt.text(row['Longitude'], row['Latitude'], 
             f"{row['Country name']} ({row['Ladder score']})", 
             color='black', fontsize=font_size, ha='right', transform=ccrs.Geodetic())

# Adjust the layout to make room for the legend
plt.subplots_adjust(left=0.2, right=0.8, top=0.9, bottom=0.1)

# Add gridlines
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

# Set title
plt.title('Happiness Ladder Score for Top and Bottom 15 Countries', fontsize=30)

plt.show()

# %% [markdown]
# The above sample plot shows the code that includes the map for the top 15 happiest and unhappiest countries.
# Source for code for coordinates: Google

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'world-happiness-report-2021.csv' is the correct file path.
Happiness_data = pd.read_csv('world-happiness-report-2021.csv')

# Make sure 'Regional indicator' and 'Ladder score' are in the DataFrame columns
if 'Regional indicator' in Happiness_data.columns and 'Ladder score' in Happiness_data.columns:
    # Group the data by 'Regional indicator' and calculate the mean ladder score
    grouped_data = Happiness_data.groupby('Regional indicator')['Ladder score'].mean().reset_index()

    # Sort the data by 'Regional indicator' to maintain the order in the box plot
    grouped_data['Regional indicator'] = pd.Categorical(grouped_data['Regional indicator'], 
                                                        categories=grouped_data['Regional indicator'].unique(), 
                                                        ordered=True)

    # Plot the box plot
    plt.figure(figsize=(12, 9))  # Adjust the size as needed
    sns.boxplot(data=Happiness_data, x='Regional indicator', y='Ladder score', order=grouped_data['Regional indicator'])
    plt.xticks(rotation=45)  # Rotate the x labels for better readability
    plt.tight_layout()  # Adjust layout to fit the plot
    plt.title('Box Plot of Average Happiness Score by Region')
    plt.show()
else:
    print("One or both of the columns 'Regional indicator' or 'Ladder score' are not present in the DataFrame.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data
# Replace 'path_to_file.csv' with the actual path to your CSV file
Happiness_data = pd.read_csv('world-happiness-report-2021.csv')

# Verify that the necessary columns are in the DataFrame
if 'Country name' in Happiness_data.columns and \
   'Regional indicator' in Happiness_data.columns and \
   'Ladder score' in Happiness_data.columns:

    # Plot the box plot
    plt.figure(figsize=(14, 8))  # Adjust the size as needed
    sns.boxplot(data=Happiness_data, x='Regional indicator', y='Ladder score')
    plt.xticks(rotation=45)  # Rotate the x labels for better readability
    plt.tight_layout()  # Adjust layout to fit the plot
    plt.title('Box Plot of Happiness Score by Country within Each Region')
    plt.show()

else:
    print("Necessary columns are not present in the DataFrame.")

# %% [markdown]
# Statistical Analysis

# %%
## Create the csv file with latitude and longitude
import pandas as pd
from geopy.geocoders import Nominatim

# Load the CSV file
df = pd.read_csv('world-happiness-report-2021.csv')

# Create an instance of Nominatim geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Function to get latitude and longitude
def get_lat_lon(country):
    location = geolocator.geocode(country, timeout=10)
    if location:
        return location.latitude, location.longitude
    else:
        return None, None

# Create new 'Latitude' and 'Longitude' columns
df['Latitude'], df['Longitude'] = zip(*df['Country name'].apply(get_lat_lon))

# Save the updated DataFrame back to CSV
df.to_csv('world-happiness-report-2021-with-coordinates.csv', index=False)

# %%
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
## Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
# Extract the unique regional indicators from the DataFrame
regional_indicators = df['Regional indicator'].unique()

# Print the list of regional indicators
print("List of Regional Indicators:")
for region in regional_indicators:
    print(region)
# Out:
# List of Regional Indicators:
# Western Europe
# North America and ANZ
# Middle East and North Africa
# Latin America and Caribbean
# Central and Eastern Europe
# East Asia
# Southeast Asia
# Commonwealth of Independent States
# Sub-Saharan Africa
# South Asia

# %%
## Define a function to create Linear Regression plots
def linear_regression(x, 
                      y, 
                      x_label, 
                      y_label, 
                      plot_title, 
                      dotcolor,
                      text_x,
                      text_y):
    
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Print the r-value
    print("The r-value is ", r_value)

    # Plot the data and regression line
    plt.scatter(x, y, color = dotcolor)
    plt.plot(x, slope * x + intercept, color='black', label='Linear Regression')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(plot_title)
    plt.legend()

    # Put linear regression equation on plot
    regression_equation_str = "y = " + str(float(f'{slope: .2f}')) + "*x + " + str(float(f'{intercept: .2f}'))
    plt.text(text_x, text_y, regression_equation_str, c="black", fontsize = 'large')

    # Show plot
    plt.show()

    # Return 
    return

# %%
# Linear regression on happines vs. GDP
x_data = df['Ladder score']
y_data = df['Logged GDP per capita']

# Call linear regression function to create plot
linear_regression(x_data, 
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "GDP per Capita ($)", 
                  "Happiness vs. GDP per Capita for All Countries", 
                  "darkseagreen",
                  6,
                  7)
# Out:
# The r-value is  0.7897596965098931

# %%
# Filter DataFrame by region
df_region = df[df['Regional indicator'] == 'Western Europe']

# Linear regression on happines vs. GDP
x_data = df_region['Ladder score']
y_data = df_region['Logged GDP per capita']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "GDP per Capita ($)", 
                  "Happiness vs. GDP per Capita for Western Europe", 
                  "darkseagreen",
                  7,
                  10.4)
# Out:
# The r-value is  0.6797150237712405

# %%
# Linear regression on happines vs. freedom
x_data = df['Ladder score']
y_data = df['Freedom to make life choices']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Freedom to Make Life Choices", 
                  "Happiness vs. Freedom to Make Life Choices for All Countries", 
                  "plum",
                  6,
                  .45)
# Out:
# The r-value is  0.6077530656580244

# %%
# Filter DataFrame by region
df_region = df[df['Regional indicator'] == 'Western Europe']

# Linear regression on happines vs. freedom
x_data = df_region['Ladder score']
y_data = df_region['Freedom to make life choices']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Freedom to Make Life Choices", 
                  "Happiness vs. Freedom to Make Life Choices for Western Europe", 
                  "plum",
                  7,
                  .65)
# Out:
# The r-value is  0.7452481702900635

# %%
# Linear regression on happines vs. freedom
x_data = df['Ladder score']
y_data = df['Social support']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Social Support", 
                  "Happiness vs. Social Support for All Countries", 
                  "cornflowerblue",
                  6,
                  .5)
# Out:
# The r-value is  0.7568876453634998

# %%
# Filter DataFrame by region
df_region = df[df['Regional indicator'] == 'Western Europe']

# Linear regression on happines vs. freedom
x_data = df_region['Ladder score']
y_data = df_region['Social support']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Social Support", 
                  "Happiness vs. Social Support for Western Countries", 
                  "cornflowerblue",
                  7,
                  .825)
# Out:
# The r-value is  0.828713584582986

# %%
# Linear regression on happines vs. freedom
x_data = df['Ladder score']
y_data = df['Generosity']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Generosity", 
                  "Happiness vs. Generosity for All Countries", 
                  "lightsalmon",
                  6,
                  .4)
# Out:
# The r-value is  -0.01779927692264076

# %%
# Filter DataFrame by region
df_region = df[df['Regional indicator'] == 'Western Europe']

# Linear regression on happines vs. freedom
x_data = df_region['Ladder score']
y_data = df_region['Generosity']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Generosity", 
                  "Happiness vs. Generosity for Western Europe", 
                  "lightsalmon",
                  7,
                  -.25)
# Out:
# The r-value is  0.5246677549797966

# %%
# Linear regression on happines vs. freedom
x_data = df['Ladder score']
y_data = df['Healthy life expectancy']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Healthy Life Expectancy", 
                  "Happiness vs. Healthy Life Expectancy for All Countries", 
                  "skyblue",
                  6,
                  52)
# Out:
# The r-value is  0.7680994550105205

# %%
# Filter DataFrame by region
df_region = df[df['Regional indicator'] == 'Western Europe']

# Linear regression on happines vs. freedom
x_data = df_region['Ladder score']
y_data = df_region['Healthy life expectancy']

# Call linear regression function to create plot
linear_regression(x_data,
                  y_data, 
                  "Happiness (Ladder Score)", 
                  "Healthy Life Expectancy", 
                  "Happiness vs. Healthy Life Expectancy for Western Europe", 
                  "skyblue",
                  7,
                  74)
# Out:
# The r-value is  -0.2763496531895233
